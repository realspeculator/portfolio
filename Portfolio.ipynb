# %% [markdown]
# ### Portfolio Returns for October 2023.

# %%
import pandas as pd
import os
import plotly.express as px
import portfolio
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed

# %%
portfolio.net_liq_df[['port_cumulative_returns']] = portfolio.net_liq_df[['port_cumulative_returns']].fillna(1)
portfolio.net_liq_df.iloc[0,:] = portfolio.net_liq_df.iloc[0,:].fillna(1)
portfolio.net_liq_df.dropna()
# Out:
#                  net_liq  port_daily_returns  port_cumulative_returns  \
# date
# 2023-10-20  1.000000e+08            1.000000                 1.000000
# 2023-10-23  1.008146e+08            0.003013                 1.008146
# 2023-10-24  1.007440e+08           -0.000700                 1.007440
# 2023-10-25  1.008456e+08            0.001008                 1.008456
# 2023-10-26  1.018890e+08            0.010346                 1.018890
# 2023-10-27  1.024990e+08            0.005988                 1.024990
# 2023-10-30  1.025990e+08            0.000975                 1.025990
# 2023-10-31  1.022117e+08           -0.003775                 1.022117
# 2023-11-01  1.021193e+08           -0.000904                 1.021193
# 2023-11-02  1.007792e+08           -0.013123                 1.007792
# 2023-11-03  1.005618e+08           -0.002157                 1.005618
# 2023-11-06  1.007987e+08            0.002355                 1.007987
# ...

# %%
portfolio.net_liq_df[['port_cumulative_returns', 'QQQ_cr', 'IWM_cr', 'DIA_cr', 'SPY_cr']].dropna().plot()
# Out:
# <Axes: xlabel='date'>
